# %% [markdown]
# # Sistema de Informação de Agravos de Notificação (SINAN)
#
# Esse notebook tem como objetivo realizar o ELT dos dados provenientes do SINAN que serão utilizados no projeto Dengue.

# %% [markdown]
# ### Libs

# %%
# %run ../config/bootstrap.py

# %%
import pandas as pd
from utils import get_project_root, save_parquet_in_chunks , load_partitioned_parquet
import basedosdados as bd

# %%
project_root = get_project_root() 
#billing_id = 'ufrgs-ppgc-dengue'

# %%
#%load_ext sql
# %reload_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.displaylimit = 100
# %sql bigquery://ufrgs-ppgc-dengue
# Out:
# Connecting to 'bigquery://ufrgs-ppgc-dengue'

# %% [markdown]
# # Datasets

# %%
# %%sql sinan <<
# SELECT ano
# ,id_municipio_notificacao as id_municipio
# ,id_estabelecimento as id_cnes
# ,  sum(CASE WHEN LOWER(classificacao_final) LIKE '%dengue%' THEN 1 ELSE 0 END) AS target
# ,  sum(CASE WHEN LOWER(evolucao_caso) LIKE '%óbito%' THEN 1 ELSE 0 END) AS obito
# ,  sum(CASE WHEN data_encerramento is not null THEN 1  ELSE 0  END) AS flag_caso_encerrado
# ,count(*) as qt
#
# from `basedosdados.br_ms_sinan.microdados_dengue`
# where 1=1
# and ano>2020
# group by 1,2,3
# Out:
# Running query in 'bigquery://ufrgs-ppgc-dengue'
# 149469 rows affected.

# %%
sinan.head()
# Out:
#     ano id_municipio  id_cnes  target  obito  flag_caso_encerrado   qt
# 0  2024      1200336  2000083       0      0                  144  144
# 1  2024      1200252  2001330       0      0                   25   25
# 2  2024      1600303  2020599       0      0                  899  900
# 3  2024      2704302  2720035       0      0                  188  188
# 4  2024      1302603  4727118       0      0                   47   48

# %%
path = project_root / "data/4_gold/dim_cnes/dim_cnes_part_1.parquet"
cnes = pd.read_parquet(path)
cnes.head()
# Out:
#    id_cnes id_unidade_cnes nu_cnpj_mantenedora id_pfpj nivel_dep  \
# 0  4013484   2408104013484      08241754000145       3         3
# 1  2589648   5201402589648      37942539000170       3         3
# 2  2052474   3549802052474                None       3         1
# 3  6270093   3549806270093      46588950000180       3         3
# 4  2589613   5201402589613      37942539000170       3         3
#
#                                     no_razao_social  \
# 0   RIO GRANDE DO NORTE SECRETARIA DA SAUDE PUBLICA
# 1               FUNDO MUNICIPAL DE SAUDE DE APDA GO
# 2    UNIMED SJRPRETO COOPERATIVA DE TRABALHO MEDICO
# 3     PREFEITURA MUNICIPAL DE SAO JOSE DO RIO PRETO
# 4  FUNDO MUNICIPAL DE SAUDE DE APARECIDA DE GOIANIA
#
#                                       no_fantasia  \
# 0                      HOSPITAL GISELDA TRIGUEIRO
# 1                                    UPA BRASICON
# 2  COMPLEXO DE SAUDE UNIMED SAO JOSE DO RIO PRETO
# 3                                UPA REGIAO NORTE
# 4                                   CAIS NOVA ERA
#
#                                         no_logradouro nu_endereco  \
# 0                                        CONEGO MONTE         110
# 1                                      RUA DAS ACASIA         S/N
# 2                                AVENIDA BADY BASSITT        4870
# 3  R MANOEL MORENO ESQ R JOSEPHA VOLTARELLI SANFELICE         130
# 4                                    AVENIDA SAO JOAO         S/N
#
#    no_complemento             no_bairro    id_cep id_regiao_saude  \
# 0            None               QUINTAS  59037170               7
# 1  ESQ C AV CHILE  RESIDENCIAL BRASICON  74975390             001
# 2            None    JAD ALTO RIO PRETO  15025000            0215
# 3            None        JARDIM ANTUNES  15047050            0215
# 4            None       JARDIM NOVA ERA  74916970             001
#
#   id_micro_regiao id_distrito_sanitario id_distrito_administrativo  \
# 0            None                    04                       None
# 1            None                  None                       None
# 2            None                  None                       None
# 3            None                  None                       None
# 4            None                  None                       None
#
#      nu_telefone nu_fax                     no_email nu_cpf         nu_cnpj  \
# 0       32327915   None                         None   None  08241754010965
# 1      3545 9953   None                         None   None            None
# 2   17 3202-1110   None  unimed@unimedripreto.com.br   None  45100138000362
# 3    17-32375315   None                         None   None            None
# 4  (62)3545 5925   None                         None   None            None
#
#   id_atividade id_clientela                 nu_alvara       data_expedicao  \
# 0           03           03                      None                 None
# 1           04           03                      None                 None
# 2           04           03  354980501-861-001673-1-2  2024-09-13 00:00:00
# 3           03           03  354980501-861-002357-1-7  2018-02-23 00:00:00
# 4           04           03                      None  2024-01-31 00:00:00
#
#   id_orgao_expedidor    data_val_lic_sani id_lic_sani id_unidade  \
# 0               None                 None        None         05
# 1               None                 None        None         73
# 2                 2   2025-09-13 00:00:00           1         73
# 3                 2   2019-02-23 00:00:00           1         73
# 4                 2   2024-12-31 00:00:00           1         20
#
#   id_turno_atendimento id_estado_gestor id_municipio_gestor  \
# 0                   06               24              240810
# 1                   06               52              520140
# 2                   06               35              354980
# 3                   06               35              354980
# 4                   06               52              520140
#
#       data_atualizacao id_usuario id_cpfdiretorcln reg_diretorcln  \
# 0  2025-08-07 00:00:00      SAUDE      68051085353           4363
# 1  2024-07-26 00:00:00     YASMIN      03258865124           None
# 2  2025-06-04 00:00:00   FERNANDA      25123834826           None
# 3  2025-08-08 00:00:00   FERNANDA      21728064805         473613
# 4  2025-01-28 00:00:00     YASMIN      01162515147           None
#
#   st_adesao_filantrop id_motivo_desab no_url          nu_latitude  \
# 0                None            None   None   -5,794974298299524
# 1                None            None   None            -16,82760
# 2                None            None   None  -20,819074142767942
# 3                None            None   None           -20,777456
# 4                None            None   None          -16,7474832
#
#           nu_longitude data_atualizacao_geolocalizacao no_usuario_geo  \
# 0  -35,209068059921265             2021-12-06 00:00:00        4013484
# 1            -49,24209             2024-07-26 00:00:00         YASMIN
# 2  -49,397743074317205             2025-04-01 00:00:00       FERNANDA
# 3           -49,403220             2019-10-01 00:00:00       FERNANDA
# 4          -49,2812776             2024-02-01 00:00:00         MARCIA
#
#   id_natureza_jur id_estab_sempre_aberto st_geracredito_gerente_sgif  \
# 0            1023                      S                        None
# 1            1031                      S                        None
# 2            2143                      S                        None
# 3            1244                      S                        None
# 4            1031                      S                        None
#
#   st_conexao_internet id_tipo_unidade no_fantasia_abrev id_gestao  \
# 0                   S            None              None         D
# 1                   S            None              None         M
# 2                   S            None              None         M
# 3                   S            None              None         M
# 4                   S            None              None         M
#
#   data_atualizacao_origem id_tipo_estabelecimento id_atividade_principal  \
# 0     2003-10-30 00:00:00                     006                    009
# 1     2002-05-22 00:00:00                     008                    007
# 2     2003-02-25 00:00:00                     008                    007
# 3     2009-06-23 00:00:00                     008                    007
# 4     2002-05-22 00:00:00                     008                    007
#
#   st_contrato_formalizado id_tipo_abrangencia st_coworking  \
# 0                       S                None            N
# 1                    None                None         None
# 2                       N                None         None
# 3                    None                None         None
# 4                       S                None         None
#
#                                                                hash  \
# 0  4c98b01f2fd50a2da5a7fcb49580d51674ee156797054d93dc8b3b301afade8b
# 1  f70e972e8d235757c25415e536078cb9b4e8e1b93b4d07280c2e961b8154df77
# 2  66339a46703b49c1bab3c25113d169321010c222f882e1944b11b9d5363cae9d
# 3  245706442b1794984d4002593ef3ea47d4e082ca8ca5a07ffbe07421cdc06207
# 4  603e683c06ba7c1292ed6742e66b4bbc3e50da43cafb25e931b6f944e1324839
#
#   data_inicio_vigencia_silver data_fim_vigencia_silver  \
# 0                  2025-08-17               9999-12-31
# 1                  2025-08-17               9999-12-31
# 2                  2025-08-17               9999-12-31
# 3                  2025-08-17               9999-12-31
# 4                  2025-08-17               9999-12-31
#
#   data_atualizacao_silver  vigencia_silver
# 0              2025-08-17                1
# 1              2025-08-17                1
# 2              2025-08-17                1
# 3              2025-08-17                1
# 4              2025-08-17                1

# %%
sinan_cnes = sinan.merge(cnes, on="id_cnes", how="left")
sinan_cnes = sinan_cnes.drop_duplicates()

# %%
sinan_cnes.head()
# Out:
#     ano id_municipio  id_cnes  target  obito  flag_caso_encerrado   qt  \
# 0  2024      1200336  2000083       0      0                  144  144
# 1  2024      1200252  2001330       0      0                   25   25
# 2  2024      1600303  2020599       0      0                  899  900
# 3  2024      2704302  2720035       0      0                  188  188
# 4  2024      1302603  4727118       0      0                   47   48
#
#   id_unidade_cnes nu_cnpj_mantenedora id_pfpj nivel_dep  \
# 0   1200332000083      04034526000143       3         3
# 1   1200252001330      84306588000104       3         3
# 2   1600302020599      05995766000177       3         3
# 3   2704302720035      12517793000108       3         3
# 4   1302604727118                None       3         1
#
#                                          no_razao_social  \
# 0                          SECRETARIA DE ESTADO DE SAUDE
# 1                 PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 2                                    MUNICIPIO DE MACAPA
# 3  UNIVERSIDADE ESTADUAL DE CIENCIAS DA SAUDE DE ALAGOAS
# 4                         HAPVIDA ASSISTENCIA MEDICA S A
#
#                                 no_fantasia  \
# 0    HOSPITAL DR ABEL PINHEIRO MACIEL FILHO
# 1  CENTRO DE SAUDE JOSE CANDIDO DE MESQUITA
# 2               PMM U B S DR MARCELO CANDIA
# 3            HOSPITAL ESCOLA DR HELVIO AUTO
# 4                     HOSPITAL RIO SOLIMOES
#
#                         no_logradouro nu_endereco no_complemento  \
# 0                              JAPIIM         S/N           None
# 1              RUA DOM JULIO MATIOLLE         S/N           None
# 2  VEREADOR JULIO MARIA PINTO PEREIRA        1329           None
# 3                CONEGO FERNANDO LYRA         S/N           None
# 4                         ALVARO MAIA        1131           None
#
#              no_bairro    id_cep id_regiao_saude id_micro_regiao  \
# 0               CENTRO  69990000             003            None
# 1               CENTRO  69934000             002            None
# 2  JARDIM FELICIDADE I  68909000             001            None
# 3             TRAPICHE  57010430            None            None
# 4         ADRIANOPOLIS  69057035            None            None
#
#   id_distrito_sanitario id_distrito_administrativo   nu_telefone nu_fax  \
# 0                  None                       None          None   None
# 1                  None                       None  (68)05463986   None
# 2                  None                       None   (96)2131115   None
# 3                  None                       None          None   None
# 4                  None                       None   85 40023633   None
#
#                    no_email nu_cpf         nu_cnpj id_atividade id_clientela  \
# 0                      None   None  04034526002006           04           03
# 1                      None   None            None           04           03
# 2                      None   None            None           04           03
# 3                      None   None  12517793000876           03           03
# 4  ADRIANYSB@HAPVIDA.COM.BR   None  63554067014652           04           03
#
#        nu_alvara       data_expedicao id_orgao_expedidor    data_val_lic_sani  \
# 0           None                 None               None                 None
# 1           None                 None               None                 None
# 2           None                 None               None                 None
# 3           None                 None               None                 None
# 4  AMP2300077780  2023-06-29 00:00:00                 2   2031-06-29 00:00:00
#
#   id_lic_sani id_unidade id_turno_atendimento id_estado_gestor  \
# 0        None         05                   06               12
# 1        None         02                   03               12
# 2        None         02                   06               16
# 3        None         07                   06               27
# 4           1         05                   04               13
#
#   id_municipio_gestor     data_atualizacao   id_usuario id_cpfdiretorcln  \
# 0              120033  2025-05-09 00:00:00       MESTRE      55824501220
# 1              120025  2025-06-05 00:00:00        SCNES      73768871215
# 2              160030  2025-07-22 00:00:00        SCNES      82397279215
# 3              270430  2025-07-28 00:00:00       GESTOR      00972439498
# 4              130260  2025-07-24 00:00:00  RIOSOLIMOES      57482667172
#
#   reg_diretorcln st_adesao_filantrop id_motivo_desab no_url  \
# 0           None                None            None   None
# 1           None                None            None   None
# 2           None                None            None   None
# 3           None                None            None   None
# 4           3312                None            None   None
#
#           nu_latitude         nu_longitude data_atualizacao_geolocalizacao  \
# 0          -7,6158847          -72,9101281             2019-08-28 00:00:00
# 1         -11,0231800           -68,458600             2019-09-23 00:00:00
# 2           0,0824155          -51,0642088             2025-04-23 00:00:00
# 3  -9,660746235997152  -35,700974464416504             2025-07-28 00:00:00
# 4          -3,0831372          -60,0359488             2024-07-24 00:00:00
#
#   no_usuario_geo id_natureza_jur id_estab_sempre_aberto  \
# 0         MESTRE            1023                      S
# 1          SCNES            1244                      N
# 2          SCNES            1244                      S
# 3         GESTOR            1112                      S
# 4         AMCNES            2054                      S
#
#   st_geracredito_gerente_sgif st_conexao_internet id_tipo_unidade  \
# 0                        None                   S            None
# 1                        None                   N            None
# 2                        None                   S            None
# 3                        None                   S            None
# 4                        None                   S            None
#
#   no_fantasia_abrev id_gestao data_atualizacao_origem id_tipo_estabelecimento  \
# 0              None         E     2003-05-13 00:00:00                     006
# 1              None         M     2001-10-30 00:00:00                     001
# 2              None         M     2001-11-01 00:00:00                     001
# 3              None         E     2003-09-03 00:00:00                     006
# 4              None         E     2024-08-04 00:00:00                     006
#
#   id_atividade_principal st_contrato_formalizado id_tipo_abrangencia  \
# 0                    009                    None                None
# 1                    012                    None                  03
# 2                    012                       S                None
# 3                    009                    None                None
# 4                    009                       N                  01
#
#   st_coworking  \
# 0            N
# 1            N
# 2            N
# 3            N
# 4            N
#
#                                                                hash  \
# 0  661ea68353772dbc157bff65e8a6bb1f3ad4781153aa9b89b95039341db1723b
# 1  5899ab3f2a1668aa7e7ad655158f69ddb51599b9d3dfa0162b5509f9dfaa57e8
# 2  b5410d9943169c92d210f3c128ce51afa064e50170c7af4847bc16a91068a6a7
# 3  f49f2784ac404f7ff23b777b877df5dac42afc3ab61464d2231f0d194608e677
# 4  19b39ad331274b622800051a5a7ec57cab61032455e0fb7db67590b562b59baf
#
#   data_inicio_vigencia_silver data_fim_vigencia_silver  \
# 0                  2025-08-17               9999-12-31
# 1                  2025-08-17               9999-12-31
# 2                  2025-08-17               9999-12-31
# 3                  2025-08-17               9999-12-31
# 4                  2025-08-17               9999-12-31
#
#   data_atualizacao_silver  vigencia_silver
# 0              2025-08-17              1.0
# 1              2025-08-17              1.0
# 2              2025-08-17              1.0
# 3              2025-08-17              1.0
# 4              2025-08-17              1.0

# %%
sinan_cnes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149469 entries, 0 to 149468
# Data columns (total 67 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   ano                              149469 non-null  int64
#  1   id_municipio                     149469 non-null  object
#  2   id_cnes                          149424 non-null  object
#  3   target                           149469 non-null  int64
#  4   obito                            149469 non-null  int64
#  5   flag_caso_encerrado              149469 non-null  int64
#  6   qt                               149469 non-null  int64
#  7   id_unidade_cnes                  147476 non-null  object
#  8   nu_cnpj_mantenedora              123058 non-null  object
#  9   id_pfpj                          147476 non-null  object
#  10  nivel_dep                        147476 non-null  object
#  11  no_razao_social                  147476 non-null  object
#  12  no_fantasia                      147476 non-null  object
#  13  no_logradouro                    147476 non-null  object
#  14  nu_endereco                      147444 non-null  object
#  15  no_complemento                   32295 non-null   object
#  16  no_bairro                        147476 non-null  object
#  17  id_cep                           147476 non-null  object
#  18  id_regiao_saude                  107854 non-null  object
#  19  id_micro_regiao                  0 non-null       object
#  20  id_distrito_sanitario            9482 non-null    object
#  21  id_distrito_administrativo       226 non-null     object
#  22  nu_telefone                      120750 non-null  object
#  23  nu_fax                           0 non-null       object
#  24  no_email                         87182 non-null   object
#  25  nu_cpf                           996 non-null     object
#  26  nu_cnpj                          27026 non-null   object
#  27  id_atividade                     147476 non-null  object
#  28  id_clientela                     146237 non-null  object
#  29  nu_alvara                        57765 non-null   object
#  30  data_expedicao                   57499 non-null   object
#  31  id_orgao_expedidor               64352 non-null   object
#  32  data_val_lic_sani                28737 non-null   object
#  33  id_lic_sani                      28857 non-null   object
#  34  id_unidade                       147476 non-null  object
#  35  id_turno_atendimento             147460 non-null  object
#  36  id_estado_gestor                 147476 non-null  object
#  37  id_municipio_gestor              147476 non-null  object
#  38  data_atualizacao                 147476 non-null  object
#  39  id_usuario                       147476 non-null  object
#  40  id_cpfdiretorcln                 146354 non-null  object
#  41  reg_diretorcln                   83928 non-null   object
#  42  st_adesao_filantrop              5626 non-null    object
#  43  id_motivo_desab                  6104 non-null    object
#  44  no_url                           4291 non-null    object
#  45  nu_latitude                      147476 non-null  object
#  46  nu_longitude                     147476 non-null  object
#  47  data_atualizacao_geolocalizacao  141950 non-null  object
#  48  no_usuario_geo                   141696 non-null  object
#  49  id_natureza_jur                  147476 non-null  object
#  50  id_estab_sempre_aberto           145603 non-null  object
#  51  st_geracredito_gerente_sgif      225 non-null     object
#  52  st_conexao_internet              145559 non-null  object
#  53  id_tipo_unidade                  0 non-null       object
#  54  no_fantasia_abrev                0 non-null       object
#  55  id_gestao                        147476 non-null  object
#  56  data_atualizacao_origem          147476 non-null  object
#  57  id_tipo_estabelecimento          144944 non-null  object
#  58  id_atividade_principal           144944 non-null  object
#  59  st_contrato_formalizado          38472 non-null   object
#  60  id_tipo_abrangencia              55562 non-null   object
#  61  st_coworking                     122523 non-null  object
#  62  hash                             147476 non-null  object
#  63  data_inicio_vigencia_silver      147476 non-null  datetime64[ms]
#  64  data_fim_vigencia_silver         147476 non-null  datetime64[ms]
#  65  data_atualizacao_silver          147476 non-null  datetime64[ms]
#  66  vigencia_silver                  147476 non-null  float64
# dtypes: datetime64[ms](3), float64(1), int64(5), object(58)
# memory usage: 76.4+ MB

# %%
output = project_root / "data/4_gold/dim_cnes_w_notifications/dim_cnes_w_notifications.parquet"
save_parquet_in_chunks(sinan_cnes,output,100,compression='brotli')
# Out:
# Salvando arquivos Parquet:   0%|          | 0/149469 [00:00<?, ?linhas/s]
# ✔️ dim_cnes_w_notifications.parquet_part_1.parquet salvo com 14.53 MB (149469 linhas)
# ✅ Todos os arquivos salvos com sucesso.
